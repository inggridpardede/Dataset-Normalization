# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
file_path = "C:/Users/User/DASI/Week 3/Data_Mahasiswa.csv"
df = pd.read_csv(file_path, delimiter=";")

# Menampilkan beberapa baris pertama dataset
df.head()
# Out:
#   Email Address         Nama Lengkap Mahasiswa      NIM   \
# 0           NaN                            NaN       NaN
# 1           NaN  Samuel Saut Royzeki Aritonang  11422026
# 2           NaN            Calvin Josep Silaen  11422038
# 3           NaN                Indah Silitonga  11422060
# 4           NaN             Asri Yohana Sirait  11422029
#
#                              Program Studi Mahasiswa Angkatan Mahasiswa  \
# 0                                                NaN                NaN
# 1  Sarjana Terapan Teknologi Rekayasa Perangkat L...               2022
# 2  Sarjana Terapan Teknologi Rekayasa Perangkat L...               2022
# 3  Sarjana Terapan Teknologi Rekayasa Perangkat L...               2022
# 4  Sarjana Terapan Teknologi Rekayasa Perangkat L...               2022
#
#   Berapa lama waktu yang Anda habiskan menggunakan laptop setiap hari?    \
# 0                                                NaN
# 1                                         9 - 11 jam
# ...

# %%
# Memilih fitur numerik yang akan dinormalisasi
numeric_features = ["Programming Skill"]

# Min-Max Scaling (0-1)
min_max_scaler = MinMaxScaler()
df_minmax = df.copy()
df_minmax[numeric_features] = min_max_scaler.fit_transform(df[numeric_features])

# Standardization (Z-Score Normalization)
standard_scaler = StandardScaler()
df_standardized = df.copy()
df_standardized[numeric_features] = standard_scaler.fit_transform(df[numeric_features])

# Menampilkan hasil normalisasi pertama untuk dibandingkan
df_comparison = df[numeric_features].head(5).copy()
df_comparison["Programming Skill (MinMax)"] = df_minmax["Programming Skill"].head(5)
df_comparison["Programming Skill (Z-Score)"] = df_standardized["Programming Skill"].head(5)

df_comparison
# Out:
#    Programming Skill  Programming Skill (MinMax)  Programming Skill (Z-Score)
# 0                 43                    0.200000                    -1.076590
# 1                 70                    0.800000                     0.992694
# 2                 42                    0.177778                    -1.153230
# 3                 36                    0.044444                    -1.613070
# 4                 56                    0.488889                    -0.080268
